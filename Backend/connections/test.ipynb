# %% [markdown]
# # Database

# %% [markdown]
# ## MongoDB

# %%
from pymongo import MongoClient
from pydantic import BaseModel as BM

client = MongoClient("mongodb://localhost:27017/")

db = client['PerceptronX']
User = db['User']
Annotations = db['Annotations']

class More(BM):
    def __init__(self):
        super().__init__()
    def Annot(ImageFile, annotations, Height, Width, Save_Location):
        bson =  {
            "Image": ImageFile,
            "Annotations": list(annotations),
            "Size": {
                "Height": Height,
                "Width": Width
            },
            "Save Location": Save_Location
        }
        
        command = db.Annotations.insert_one(bson)
        return "Recorded successfully!" if command else "Record failed!"
    
    
    def users():
        pass
    
m = More
x = m.Annot(ImageFile="Image3.png", annotations=[3, 5, 7, 9], Width=850, Height=1340, Save_Location="../Sample")
x
# Out:
# 'Recorded successfully!'

# %%
res = db.annotations.find()
for i in res:
    print(i)

# %%
from pymongo import MongoClient
from pydantic import BaseModel as BM

client = MongoClient("mongodb://localhost:27017/")

db = client['PerceptronX']
User = db['User']
Annotations = db['annotations']

def serialize_document(doc):
    """Convert MongoDB document to a JSON-serializable format"""
    return {
        "id": str(doc["_id"]),
        "user_id": doc["user_id"],
        "image": doc["image"],
        "annotations": doc["annotations"],
        "size": doc["size"],
        "save_location": doc["save_location"],
        "model_used": doc["model_used"],
        "timestamp": doc["timestamp"].isoformat(),
        "status": doc["status"],
        "confidence_threshold": doc["confidence_threshold"],
        "processing_time": doc["processing_time"],
        "device": doc["device"]
    }

# %%
from pymongo import MongoClient

def get_Mongo_db(collection_name): #MongoDB
    MONGO_URI = "mongodb://localhost:27017"
    DB_NAME = "PerceptronX"
    COLLECTION_NAME = collection_name

    client = MongoClient(MONGO_URI)
    db = client[DB_NAME]
    collection = db[COLLECTION_NAME]
    return collection

res = get_Mongo_db("Annotations").find()
[i for i in res]
# Out:
# [{'_id': ObjectId('67efe866f0e1e830be551cf4'),
#   'Image': 'Image3.png',
#   'Annotations': [3, 5, 7, 9],
#   'Size': {'Height': 1340, 'Width': 850},
#   'Save Location': '../Sample'}]

# %% [markdown]
# ## MySql

# %%
import mysql.connector

def get_Mysql_db(): #Mysql
    """>>> Example usecase: 
    --code
    async def registerUser(result: Register): # Mysql 
        db = get_Mysql_db()
        cursor = db.cursor()
    
        hashed_password = bcrypt.hashpw(result.password.encode("utf-8"), bcrypt.gensalt())

        try:
            cursor.execute(
                "INSERT INTO users (username, email, password_hash) VALUES (%s, %s, %s)",
                (result.username, result.email, hashed_password.decode("utf-8"))
            )
            db.commit()
            return RedirectResponse(url="/", status_code=303)
        except mysql.connector.IntegrityError:
            return {"error": "Username or email already exists."}
        finally:
            cursor.close()
            db.close()
    """
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="",
        database="perceptronx"
    )
    
res = get_Mysql_db() 
print(True) if res else print(False)
# Out:
# True

# %%
import mysql.connector

def get_mysql_db():
    """
    Connect to MySQL database.

    >>> Example use case:
    async def registerUser(result: Register):
        db = get_mysql_db()
        cursor = db.cursor()
        hashed_password = bcrypt.hashpw(result.password.encode("utf-8"), bcrypt.gensalt())
        try:
            cursor.execute(
                "INSERT INTO users (username, email, password_hash) VALUES (%s, %s, %s)",
                (result.username, result.email, hashed_password.decode("utf-8"))
            )
            db.commit()
            return RedirectResponse(url="/", status_code=303)
        except mysql.connector.IntegrityError:
            return {"error": "Username or email already exists."}
        finally:
            cursor.close()
            db.close()
    """
    return mysql.connector.connect(
        host="localhost",
        user="root",
        password="root",
        database="perceptronx"
    )

async def user_profile(user_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("SELECT * FROM users WHERE user_id = %s", (user_id,))
        return cursor.fetchall()
    except Exception as e:
        print(f"Error fetching patient profile: {e}")
        return []
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()

async def user_patient_profile(user_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("SELECT * FROM Patients WHERE user_id = %s", (user_id,))
        return cursor.fetchall()
    except Exception as e:
        print(f"Error fetching patient profile: {e}")
        return []
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()

async def get_therapist_data(therapist_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("SELECT * FROM Therapists WHERE id = %s", (therapist_id,))
        return cursor.fetchall()
    except Exception as e:
        print(f"Error fetching therapist profile: {e}")
        return []
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()

async def get_appointment_data(patient_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("SELECT * FROM Appointments WHERE patient_id = %s", (patient_id,))
        return cursor.fetchall()
    except Exception as e:
        print(f"Error fetching appointment data: {e}")
        return []
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()

async def get_treatment_plans(patient_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("SELECT * FROM TreatmentPlans WHERE patient_id = %s", (patient_id,))
        return cursor.fetchall()
    except Exception as e:
        print(f"Error fetching treatment plans: {e}")
        return []
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()

async def get_treatment_plan_exercises(plan_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("""
            SELECT * FROM TreatmentPlanExercises 
            WHERE plan_id = %s
        """, (plan_id,))
        exercises = cursor.fetchall()
        
        for exercise in exercises:
            cursor.execute("""
                SELECT * FROM Exercises 
                WHERE exercise_id = %s
            """, (exercise['exercise_id'],))
            exercise_details = cursor.fetchone()
            if exercise_details:
                exercise['exercise_details'] = exercise_details
        
        return exercises
    except Exception as e:
        print(f"Error fetching treatment plan exercises: {e}")
        return []
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()
            
async def get_exercise_details(exercise_id):
    db = get_mysql_db()
    cursor = None
    try:
        cursor = db.cursor(dictionary=True)
        cursor.execute("SELECT * FROM Exercises WHERE exercise_id = %s", (exercise_id,))
        return cursor.fetchone()
    except Exception as e:
        print(f"Error fetching exercise details: {e}")
        return None
    finally:
        if cursor:
            cursor.close()
        if db:
            db.close()
            
async def main(user_id):
    patient_profile = await user_patient_profile(user_id)
    if not patient_profile:
        print("No patient profile found.")
        return
    
    therapist_id = patient_profile[0]['therapist_id']
    patient_id = patient_profile[0]['patient_id']
    
    therapist_data = await get_therapist_data(therapist_id)
    appointments = await get_appointment_data(patient_id)
    treatment_plans = await get_treatment_plans(patient_id)
    
    print(f"patient_profile: {patient_profile}")
    print(f"therapist_data: {therapist_data}")
    print(f"appointments: {appointments}")
    print(f"treatment_plans: {treatment_plans}")
    
    for plan in treatment_plans:
        plan_exercises = await get_treatment_plan_exercises(plan['plan_id'])
        print(f"Plan {plan['name']} exercises: {plan_exercises}")
        
        for exercise in plan_exercises:
            exercise_details = await get_exercise_details(exercise['exercise_id'])
            print(f"Exercise {exercise['exercise_id']} details: {exercise_details}")

await main(48)
# Out:
# patient_profile: [{'patient_id': 16, 'therapist_id': 14, 'first_name': 'Sample', 'last_name': 'Sample2', 'email': '1@gmail.com', 'phone': '09434324323', 'date_of_birth': None, 'address': 'None', 'diagnosis': 'Lack of energy', 'status': 'Active', 'notes': 'None', 'created_at': datetime.datetime(2025, 4, 25, 1, 33, 57), 'updated_at': datetime.datetime(2025, 4, 25, 13, 59, 31), 'user_id': 48}]
# therapist_data: [{'id': 14, 'first_name': 'Rossy', 'last_name': 'Cross', 'company_email': 'RoseGarden@gmail.com', 'password': '$2b$12$jGmSjoXIUfRHceNoU5YhqeVAutt.GoMxfSOL.bnN/WLXV9/PY811C', 'profile_image': 'therapist_14_1745140730.jpg', 'bio': 'I love cooking my favorite foods every day', 'experience_years': 10, 'specialties': '["Depression", "Anxiety"]', 'education': '["University of Oxford"]', 'languages': '["English", "Spanish"]', 'address': 'Manila, Philippines', 'rating': 4.5, 'review_count': 65, 'is_accepting_new_patients': 1, 'average_session_length': 60}]
# appointments: [{'appointment_id': 36, 'patient_id': 16, 'therapist_id': 14, 'appointment_date': datetime.date(2025, 4, 25), 'appointment_time': datetime.timedelta(seconds=32400), 'duration': 60, 'status': 'Scheduled', 'notes': 'Type: video\n', 'created_at': datetime.datetime(2025, 4, 25, 1, 33, 57), 'updated_at': datetime.datetime(2025, 4, 25, 1, 33, 57)}, {'appointment_id': 37, 'patient_id': 16, 'therapist_id': 14, 'appointment_date': datetime.date(2025, 4, 28), 'appointment_time': datetime.timedelta(seconds=36000), 'duration': 60, 'status': 'Scheduled', 'notes': 'Type: phone\n', 'created_at': datetime.datetime(2025, 4, 25, 1, 34, 25), 'updated_at': datetime.datetime(2025, 4, 25, 1, 34, 25)}]
# treatment_plans: [{'plan_id': 7, 'patient_id': 16, 'therapist_id': 14, 'name': 'Knee Rehabilitation Plan', 'description': 'To make you feel more powerful and energetic', 'start_date': datetime.date(2025, 4, 25), 'end_date': datetime.date(2025, 6, 20), 'status': 'Active', 'created_at': datetime.datetime(2025, 4, 25, 12, 50, 46), 'updated_at': datetime.datetime(2025, 4, 25, 12, 50, 46)}]
# Plan Knee Rehabilitation Plan exercises: [{'plan_exercise_id': 10, 'plan_id': 7, 'exercise_id': 16, 'sets': 3, 'repetitions': 8, 'frequency': 'Daily', 'duration': 10, 'notes': 'More challenges for you!', 'created_at': datetime.datetime(2025, 4, 25, 12, 50, 46), 'exercise_details': {'exercise_id': 16, 'therapist_id': None, 'category_id': 1, 'name': '20 Hip Thrusts', 'description': 'EQUIPMENT NEEDED : COUCH', 'video_url': 'https://www.youtube.com/watch?v=E0pOOfQr0zI', 'video_type': 'youtube', 'video_size': None, 'video_filename': None, 'duration': 5, 'difficulty': 'Beginner', 'instructions': 'Place feet shoulder-width apart on the floor, back on the couch.\r\nHinge at the hips, moving them toward the floor\r\nUsing your glutes, bring your hips up toward the ceiling again.', 'created_at': datetime.datetime(2025, 4, 20, 20, 12, 1), 'updated_at': datetime.datetime(2025, 4, 20, 20, 54, 7)}}, {'plan_exercise_id': 11, 'plan_id': 7, 'exercise_id': 17, 'sets': 3, 'repetitions': 10, 'frequency': 'Daily', 'duration': 10, 'notes': 'For upper body', 'created_at': datetime.datetime(2025, 4, 25, 12, 50, 46), 'exercise_details': {'exercise_id': 17, 'therapist_id': None, 'category_id': 2, 'name': '20 Shoulder Taps', 'description': 'EQUIPMENT NEEDED : COUCH', 'video_url': 'https://www.youtube.com/watch?v=6-8E4Nirh9s', 'video_type': 'youtube', 'video_size': None, 'video_filename': None, 'duration': 5, 'difficulty': 'Beginner', 'instructions': '- Pushup position.\r\n- Touch R hand to L shoulder, back to starting position.\r\n- Switch and repeat.\r\n\r\nREST FOR 1 - 2 MINS AFTER COMPLETING\r\nEXERCISES 1 - 5\r\nREPEAT 3 - 5 TIMES', 'created_at': datetime.datetime(2025, 4, 20, 20, 22, 24), 'updated_at': datetime.datetime(2025, 4, 20, 20, 54, 28)}}, {'plan_exercise_id': 12, 'plan_id': 7, 'exercise_id': 18, 'sets': 3, 'repetitions': 10, 'frequency': 'Daily', 'duration': 10, 'notes': 'For balance power', 'created_at': datetime.datetime(2025, 4, 25, 12, 50, 46), 'exercise_details': {'exercise_id': 18, 'therapist_id': None, 'category_id': 5, 'name': '15 Supermans', 'description': 'Lay on stomach with arms outstretched in front.', 'video_url': 'https://www.youtube.com/watch?v=6-8E4Nirh9s', 'video_type': 'youtube', 'video_size': None, 'video_filename': None, 'duration': 2, 'difficulty': 'Beginner', 'instructions': '- Lay on stomach with arms outstretched in front.\r\n- Simultaneously raise arms, trunk, and lower body.\r\n- Lower back down and repeat.', 'created_at': datetime.datetime(2025, 4, 20, 20, 27, 49), 'updated_at': datetime.datetime(2025, 4, 23, 18, 26, 12)}}]
# Exercise 16 details: {'exercise_id': 16, 'therapist_id': None, 'category_id': 1, 'name': '20 Hip Thrusts', 'description': 'EQUIPMENT NEEDED : COUCH', 'video_url': 'https://www.youtube.com/watch?v=E0pOOfQr0zI', 'video_type': 'youtube', 'video_size': None, 'video_filename': None, 'duration': 5, 'difficulty': 'Beginner', 'instructions': 'Place feet shoulder-width apart on the floor, back on the couch.\r\nHinge at the hips, moving them toward the floor\r\nUsing your glutes, bring your hips up toward the ceiling again.', 'created_at': datetime.datetime(2025, 4, 20, 20, 12, 1), 'updated_at': datetime.datetime(2025, 4, 20, 20, 54, 7)}
# Exercise 17 details: {'exercise_id': 17, 'therapist_id': None, 'category_id': 2, 'name': '20 Shoulder Taps', 'description': 'EQUIPMENT NEEDED : COUCH', 'video_url': 'https://www.youtube.com/watch?v=6-8E4Nirh9s', 'video_type': 'youtube', 'video_size': None, 'video_filename': None, 'duration': 5, 'difficulty': 'Beginner', 'instructions': '- Pushup position.\r\n- Touch R hand to L shoulder, back to starting position.\r\n- Switch and repeat.\r\n\r\nREST FOR 1 - 2 MINS AFTER COMPLETING\r\nEXERCISES 1 - 5\r\nREPEAT 3 - 5 TIMES', 'created_at': datetime.datetime(2025, 4, 20, 20, 22, 24), 'updated_at': datetime.datetime(2025, 4, 20, 20, 54, 28)}
# Exercise 18 details: {'exercise_id': 18, 'therapist_id': None, 'category_id': 5, 'name': '15 Supermans', 'description': 'Lay on stomach with arms outstretched in front.', 'video_url': 'https://www.youtube.com/watch?v=6-8E4Nirh9s', 'video_type': 'youtube', 'video_size': None, 'video_filename': None, 'duration': 2, 'difficulty': 'Beginner', 'instructions': '- Lay on stomach with arms outstretched in front.\r\n- Simultaneously raise arms, trunk, and lower body.\r\n- Lower back down and repeat.', 'created_at': datetime.datetime(2025, 4, 20, 20, 27, 49), 'updated_at': datetime.datetime(2025, 4, 23, 18, 26, 12)}

# %%
from pydantic import BaseModel

class User_Data(BaseModel):
    username: str
    email: str
    joined: str

db = get_Mysql_db()
cursor = db.cursor()

query = "SELECT username, email, created_at FROM users"
cursor.execute(query)

rows = cursor.fetchall()

users = [User_Data(username=row[0], email=row[1], joined=str(row[2])) for row in rows]

for user in users:
    print(user)
# Out:
# username='111' email='111@gmail.com' joined='2025-04-06 20:36:36'
# username='222' email='222@gmail.com' joined='2025-04-07 20:07:06'
# username='444' email='444@gmail.com' joined='2025-04-07 20:08:02'
# username='selwynjayme' email='selwynjaymegwapo@gmail.com' joined='2025-04-09 13:04:30'

# %% [markdown]
# ## Redis

# %%
import redis.asyncio as redis
import uuid
import os
from dotenv import load_dotenv

load_dotenv()

REDIS_HOST = os.getenv("REDIS_HOST", "localhost")
REDIS_PORT = int(os.getenv("REDIS_PORT", 6379))

r = redis.Redis(host=REDIS_HOST, port=REDIS_PORT, decode_responses=True)

SESSION_TTL = 3600

async def create_session(data: dict, remember_me: bool = False):
    session_id = str(uuid.uuid4())
    await r.hmset(session_id, data)
    if not remember_me:
        await r.expire(session_id, SESSION_TTL)  
    return session_id


async def get_session(session_id: str):
    return await r.hgetall(session_id)

async def delete_session(session_id: str):
    await r.delete(session_id)

# %% [markdown]
# # AI Related

# %% [markdown]
# ## Computer Vision

# %%
import cv2
import mediapipe as mp
import time
import pygame
import subprocess
import os
import numpy as np

def process_video_with_pose_detection(video_path):
    pygame.init()
    
    mp_pose = mp.solutions.pose
    mp_drawing = mp.solutions.drawing_utils
    pose = mp_pose.Pose(
        min_detection_confidence=0.3,
        min_tracking_confidence=0.3,
        static_image_mode=False,
        model_complexity=0
    )
    
    output_dir = "uploads/exercise_videos/processed_videos"
    os.makedirs(output_dir, exist_ok=True)
    
    original_filename = os.path.basename(video_path).split('.')[0]
    output_path = os.path.join(output_dir, f"{original_filename}_processed_temp.mp4")
    final_output = os.path.join(output_dir, f"{original_filename}_processed.mp4")
    
    def extract_audio():
        temp_audio = "temp_audio.mp3"
        if os.path.exists(temp_audio):
            os.remove(temp_audio)
        
        try:
            subprocess.call(['ffmpeg', '-i', video_path, '-q:a', '0', '-map', 'a', temp_audio, '-y'], 
                            stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
            return temp_audio
        except Exception as e:
            print(f"Error extracting audio: {e}")
            return None
    
    audio_file = extract_audio()
    
    cap = cv2.VideoCapture(video_path)
    
    fps = cap.get(cv2.CAP_PROP_FPS)
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
    print(f"Video FPS: {fps}")
    
    scale_factor = 0.5
    target_width = int(width * scale_factor)
    target_height = int(height * scale_factor)
    
    fourcc = cv2.VideoWriter_fourcc(*'mp4v')  
    out = cv2.VideoWriter(output_path, fourcc, fps, (target_width, target_height))
    
    frame_duration = 1.0 / fps
    
    if audio_file:
        pygame.mixer.music.load(audio_file)
        pygame.mixer.music.play()
    
    start_time = time.time()
    next_frame_time = start_time
    frame_count = 0
    real_fps = 0
    processing_times = []
    
    print("Starting synchronized playback and recording...")
    
    while cap.isOpened():
        current_time = time.time()
        
        if current_time < next_frame_time:
            time.sleep(max(0, (next_frame_time - current_time) / 2))
            continue
        
        ret, frame = cap.read()
        if not ret:
            break
        
        frame = cv2.resize(frame, (target_width, target_height))
        
        start_process = time.time()
        rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        results = pose.process(rgb_frame)
        process_time = time.time() - start_process
        processing_times.append(process_time)
        
        if results.pose_landmarks:
            mp_drawing.draw_landmarks(
                frame, 
                results.pose_landmarks, 
                mp_pose.POSE_CONNECTIONS,
                mp_drawing.DrawingSpec(color=(0,255,0), thickness=2, circle_radius=2),
                mp_drawing.DrawingSpec(color=(0,0,255), thickness=2)
            )
        
        out.write(frame)
        
        cv2.imshow('Pose Detection with Audio', frame)
        
        frame_count += 1
        next_frame_time = start_time + (frame_count * frame_duration)
        
        if current_time > next_frame_time + (2 * frame_duration):
            frames_behind = int((current_time - next_frame_time) / frame_duration)
            print(f"Falling behind by {frames_behind} frames, skipping ahead")
            
            for _ in range(min(frames_behind, 10)):  
                ret = cap.grab()
                if not ret:
                    break
                frame_count += 1
            
            next_frame_time = start_time + (frame_count * frame_duration)
        
        if frame_count % 30 == 0:
            elapsed = time.time() - start_time
            real_fps = frame_count / elapsed
            avg_process_time = np.mean(processing_times) if processing_times else 0
            processing_times = []
            
            sync_diff = (time.time() - start_time) - (frame_count * frame_duration)
            sync_frames = sync_diff * fps
            
            cv2.putText(frame, f"FPS: {real_fps:.1f}/{fps:.1f}", 
                        (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
            cv2.putText(frame, f"Sync: {sync_frames:.1f} frames", 
                        (10, 60), cv2.FONT_HERSHEY_SIMPLEX, 0.7, 
                        (0, 255, 0) if abs(sync_frames) < 1 else (0, 0, 255), 2)
            cv2.putText(frame, f"Process time: {avg_process_time*1000:.0f}ms", 
                        (10, 90), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2)
        
        key = cv2.waitKey(1) & 0xFF
        if key == ord('q'):
            break
        elif key == ord('r'):  
            start_time = time.time() - (frame_count * frame_duration)
            print("Resynchronized")
    
    cap.release()
    out.release()  
    pygame.mixer.music.stop()
    pygame.quit()
    cv2.destroyAllWindows()
    
    if audio_file and os.path.exists(audio_file):
        try:
            os.remove(audio_file)
        except:
            pass
    
    print("Adding audio to the saved video...")
    subprocess.call(['ffmpeg', '-i', output_path, '-i', video_path, '-c:v', 'copy', 
                     '-map', '0:v', '-map', '1:a', '-shortest', final_output, '-y'],
                    stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL)
    
    if os.path.exists(output_path):
        os.remove(output_path)
    
    print(f"Video saved as {final_output}")
    return final_output

video_url = "/home/zkllmt/Documents/AI_Section/Android_Projects/PerceptronX/Backend/uploads/exercise_videos/98d5817b-223a-4e59-8e5c-66b7eb6cafc3.mp4"
output_video_path = process_video_with_pose_detection(video_url)
print(f"Processed video saved at: {output_video_path}")

# %% [markdown]
# ## Simple Machine Learning features

# %% [markdown]
# ## Natural Language Processing
